# %%
from agents.eyes import Eyes, tools
eyes = Eyes()

# %%
# !pip install openai opencv-python-headless

# %%
lidar_path = "/home/nevpit/data/FNA_A01_2013_laz_4.laz"  # path to your LiDAR file
point_arrays = eyes.analyze_lidar(lidar_path)

# %%
arr = point_arrays[0]
print(arr.dtype.names, arr.shape)
# Out:
# ('X', 'Y', 'Z', 'Intensity', 'ReturnNumber', 'NumberOfReturns', 'ScanDirectionFlag', 'EdgeOfFlightLine', 'Classification', 'Synthetic', 'KeyPoint', 'Withheld', 'Overlap', 'ScanAngleRank', 'UserData', 'PointSourceId', 'GpsTime') (9604103,)

# %%
dtm_result = eyes.lidar_tile_dtm(
    lidar_path, 
    resolution=1.0,               # 1m output resolution
    out_dir="output/tile1",       # folder to save GeoTIFFs
    return_paths=True            # return file paths instead of numpy arrays
)
# Out:
# /home/nevpit/miniconda3/envs/casiquiare/lib/python3.12/site-packages/osgeo/gdal.py:311: FutureWarning: Neither gdal.UseExceptions() nor gdal.DontUseExceptions() has been explicitly called. In GDAL 4.0, exceptions will be enabled by default.
#   warnings.warn(
